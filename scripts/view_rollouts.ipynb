# %%
import pandas as pd

df = pd.read_json('/iris/u/asap7772/rl_behaviors_verl_stable/ppo/insight-grpo-qwenwarmstart-longcot-2epoch/0_rollouts.json')
df
# Out:
#                                                  input  \
# 0    user\nuser\nYou are a helpful AI Assistant tha...
# 1    user\nuser\nYou are a helpful AI Assistant tha...
# 2    user\nuser\nYou are a helpful AI Assistant tha...
# 3    user\nuser\nYou are a helpful AI Assistant tha...
# 4    user\nuser\nYou are a helpful AI Assistant tha...
# ..                                                 ...
# 795  user\nuser\nYou are a helpful AI Assistant tha...
# 796  user\nuser\nYou are a helpful AI Assistant tha...
# 797  user\nuser\nYou are a helpful AI Assistant tha...
# 798  user\nuser\nYou are a helpful AI Assistant tha...
# 799  user\nuser\nYou are a helpful AI Assistant tha...
#
#                                                 output     score ref_score  \
# 0    Okay, let's see. The first paper is about Meta... -0.439303   unknown
# 1    Okay, let's see. The first paper is about Meta... -0.439303   unknown
# 2    Okay, let's see. The first paper is about Meta... -0.439303   unknown
# ...

# %%
print(df['output'].iloc[0])
# Out:
# Okay, let's see. The first paper is about MetaDistil, a method that uses meta learning to improve knowledge distillation. The idea is that the teacher model learns better by considering the performance of the student, which is a meta-learning approach. The second paper is about event extraction using prompt-based learning, which simplifies the process by automatically using label semantics without needing templates.
#
# ...
